# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import pytz
from io import StringIO

file_path = "/home/jovyan/work/General/Group/Data/Landt_cyclers/CoinCell_007_FT_012424007_002_7.csv"

data = pd.read_csv(file_path, on_bad_lines='skip', sep=',',header=16)
data = data[pd.to_numeric(data['Record'], errors='coerce').notna()]
data = data[0:7000]

# Convert 'TestTime' to datetime objects
# data['TestTime'] = pd.to_datetime(data['TestTime'], format='%H:%M:%S.%f')
print(data.head())
print(len(data))
plt.plot(data['Voltage/V'])
plt.xlabel('Time (seconds)')
plt.ylabel('Voltage (V)')
plt.title('Time vs Voltage')
plt.show()
# Out:
#   Record     TestTime Current/uA Capacity/uAh Voltage/V
# 0     12  00:10:00.00    -1000.0          0.0    0.7409
# 1     13  00:10:00.52    -1000.0          0.3    0.6484
# 2     14  00:10:01.01    -1000.0          0.4    0.5187
# 3     15  00:10:01.52    -1000.0          0.5    0.4202
# 4     16  00:10:02.00    -1000.0          0.7    0.3477
# 7000
